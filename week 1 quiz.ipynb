# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("fuel_ferc1.csv")

# %%
df
# Out:
#                      record_id  utility_id_ferc1  report_year  \
# 0        f1_fuel_1994_12_1_0_7                 1         1994
# 1       f1_fuel_1994_12_1_0_10                 1         1994
# 2        f1_fuel_1994_12_2_0_1                 2         1994
# 3        f1_fuel_1994_12_2_0_7                 2         1994
# 4       f1_fuel_1994_12_2_0_10                 2         1994
# ...                        ...               ...          ...
# 29518  f1_fuel_2018_12_12_0_13                12         2018
# 29519   f1_fuel_2018_12_12_1_1                12         2018
# 29520  f1_fuel_2018_12_12_1_10                12         2018
# 29521  f1_fuel_2018_12_12_1_13                12         2018
# 29522  f1_fuel_2018_12_12_1_14                12         2018
#
#            plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0                  rockport                coal       ton        5377489.0
# ...

# %%
df.isnull().sum()
# Out:
# record_id                         0
# utility_id_ferc1                  0
# report_year                       0
# plant_name_ferc1                  0
# fuel_type_code_pudl               0
# fuel_unit                       180
# fuel_qty_burned                   0
# fuel_mmbtu_per_unit               0
# fuel_cost_per_unit_burned         0
# fuel_cost_per_unit_delivered      0
# fuel_cost_per_mmbtu               0
# dtype: int64

# %%
df.describe()
# Out:
#        utility_id_ferc1   report_year  fuel_qty_burned  fuel_mmbtu_per_unit  \
# count      29523.000000  29523.000000     2.952300e+04         29523.000000
# mean         118.601836   2005.806050     2.622119e+06             8.492111
# std           74.178353      7.025483     9.118004e+06            10.600220
# min            1.000000   1994.000000     1.000000e+00             0.000001
# 25%           55.000000   2000.000000     1.381700e+04             1.024000
# 50%          122.000000   2006.000000     2.533220e+05             5.762694
# 75%          176.000000   2012.000000     1.424034e+06            17.006000
# max          514.000000   2018.000000     5.558942e+08           341.260000
#
#        fuel_cost_per_unit_burned  fuel_cost_per_unit_delivered  \
# count               29523.000000                  2.952300e+04
# mean                  208.649031                  9.175704e+02
# std                  2854.490090                  6.877593e+04
# ...

# %%
(180/29523)*100
# Out:
# 0.609694136774718

# %%
df.sort_values("fuel_cost_per_unit_delivered", ascending=False)
# Out:
#                      record_id  utility_id_ferc1  report_year  \
# 3564     f1_fuel_1997_12_9_0_8                 9         1997
# 3244     f1_fuel_1996_12_9_0_8                 9         1996
# 3565    f1_fuel_1997_12_9_0_11                 9         1997
# 3245    f1_fuel_1996_12_9_0_14                 9         1996
# 3566    f1_fuel_1997_12_9_0_14                 9         1997
# ...                        ...               ...          ...
# 7733   f1_fuel_2000_12_194_3_3               194         2000
# 7736   f1_fuel_2000_12_194_3_6               194         2000
# 12975  f1_fuel_2004_12_210_1_6               210         2004
# 16634  f1_fuel_2007_12_177_2_4               177         2007
# 17525  f1_fuel_2008_12_177_1_1               177         2008
#
#           plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 3564          peach bt 2&3             nuclear    gramsU         210474.0
# ...

# %%
df.sort_values("fuel_cost_per_unit_burned", ascending=True)
# Out:
#                       record_id  utility_id_ferc1  report_year  \
# 7733    f1_fuel_2000_12_194_3_3               194         2000
# 7736    f1_fuel_2000_12_194_3_6               194         2000
# 7730   f1_fuel_2000_12_194_2_15               194         2000
# 11242   f1_fuel_2003_12_281_1_4               281         2003
# 2123    f1_fuel_1995_12_194_5_9               194         1995
# ...                         ...               ...          ...
# 22991    f1_fuel_2012_12_7_7_13                 7         2012
# 21483    f1_fuel_2011_12_7_7_13                 7         2011
# 24577   f1_fuel_2014_12_177_2_7               177         2014
# 20719   f1_fuel_2011_12_132_1_2               132         2011
# 25127   f1_fuel_2014_12_147_0_2               147         2014
#
#           plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 7733   nelson dewey unit 2               waste       ton             39.0
# ...

# %%
from scipy.stats import kurtosis
from scipy.stats import skew

# %%
skew(df["fuel_qty_burned"], bias=False)
# Out:
# 15.8514954691095

# %%
kurtosis(df["fuel_qty_burned"], bias=False)
# Out:
# 651.3694501337731

# %%
filter = df["report_year"] == 1994
fuel_1994 = df[filter]

filter2 = df["report_year"] == 1998
fuel_1998 = df[filter2]

# %%
diff = fuel_1998["fuel_cost_per_unit_burned"].sum()  - fuel_1994["fuel_cost_per_unit_burned"].sum()
total = fuel_1998["fuel_cost_per_unit_burned"].sum() + fuel_1994["fuel_cost_per_unit_burned"].sum()

# %%
(diff/total)*100
# Out:
# -30.494194704175364

# %%
gas = df[df["fuel_type_code_pudl"]== "gas"]
gas["fuel_cost_per_unit_burned"].sum() /11486
# Out:
# 13.659396569737071

# %%
oil = df[df["fuel_type_code_pudl"]== "oil"]
oil["fuel_cost_per_unit_burned"].sum() /8064
# Out:
# 168.87708568948415

# %%
waste = df[df["fuel_type_code_pudl"]== "waste"]
waste["fuel_cost_per_unit_burned"].sum() /441
# Out:
# 19.518122448979593

# %%
df["fuel_type_code_pudl"].value_counts()
# Out:
# gas        11486
# coal        8547
# oil         8064
# nuclear      818
# waste        441
# other        167
# Name: fuel_type_code_pudl, dtype: int64
